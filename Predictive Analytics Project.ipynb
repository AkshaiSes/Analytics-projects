# %%
import pandas as pd
import numpy as np

# %%
coffee = pd.read_csv('coffee_groc_1114_1165', delim_whitespace=True)

# %%
delivery = pd.read_csv('Delivery.csv')

# %%
time = pd.read_csv('IRI week translation.csv')

# %%
coffee.head(2)
# Out:
#    IRI_KEY  WEEK  SY  GE   VEND   ITEM  UNITS  DOLLARS     F    D   PR
# 0   253422  1114   0   1  43000  75305      1     6.99  NONE  0.0  0.0
# 1   253422  1114   0   1  43000  70170      2    13.98  NONE  0.0  0.0

# %%
delivery.head(2)
# Out:
#    IRI_KEY  OU    EST_ACV        Market_Name  Open  Clsd MskdName
# 0   200039  GR   9.709999  BUFFALO/ROCHESTER   539  1219  Chain87
# 1   200171  GR  27.690990          MILWAUKEE   522  9998  Chain97

# %%
delivery.isna().sum()
# Out:
# IRI_KEY        0
# OU             0
# EST_ACV        0
# Market_Name    0
# Open           0
# Clsd           0
# MskdName       0
# dtype: int64

# %%
time.head(2)
# Out:
#    WEEK Calendar week starting on Calendar week ending on  Unnamed: 3  \
# 0  1138                 18-Jun-01               24-Jun-01         NaN
# 1  1139                 25-Jun-01                1-Jul-01         NaN
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 10 Unnamed: 11
# 0          NaN         NaN
# 1          NaN         NaN

# %%
time.isna().sum()
# Out:
# WEEK                           0
# Calendar week starting on      0
# Calendar week ending on        0
# Unnamed: 3                   526
# Unnamed: 4                   526
# Unnamed: 5                   526
# Unnamed: 6                   526
# Unnamed: 7                   526
# Unnamed: 8                   526
# Unnamed: 9                   526
# Unnamed: 10                  526
# Unnamed: 11                  525
# dtype: int64

# %%
coffee.isna().sum()
# Out:
# IRI_KEY    0
# WEEK       0
# SY         0
# GE         0
# VEND       0
# ITEM       0
# UNITS      0
# DOLLARS    1
# F          1
# D          1
# PR         1
# dtype: int64

# %%
coffee = coffee.dropna()

# %%
coffee.PR.unique()
# Out:
# array([0., 1.])

# %%
coffee.D.unique()
# Out:
# array([0., 1., 2.])

# %%
coffee.F.unique()
# Out:
# array(['NONE', 'B', 'A', 'A+', 'C'], dtype=object)

# %%
coffee.UNITS.unique()
# Out:
# array([   1,    2,    4, ..., 1448, 1925,  980])

# %%
coffee.GE.unique()
# Out:
# array([1, 2, 3, 4, 6, 5])

# %%
coffee.SY.unique()
# Out:
# array([ 0,  7, 88,  6,  8,  1, 26, 27])

# %%
coffee['VEND'].value_counts()
# Out:
# 25500    1185527
# 43000    1082745
# 99998     717672
# 75101     493210
# 62111     437090
#           ...
# 76238          1
# 36462          1
# 71194          1
# 67977          1
# 94581          1
# Name: VEND, Length: 207, dtype: int64

# %%
coffee['ITEM'].value_counts()
# Out:
# 70522    65843
# 80258    64945
# 80273    64092
# 81121    61219
# 51       56150
#          ...
# 50540        1
# 15701        1
# 3068         1
# 45415        1
# 30780        1
# Name: ITEM, Length: 2839, dtype: int64

# %%
coffee.head(2)
# Out:
#    IRI_KEY  WEEK  SY  GE   VEND   ITEM  UNITS  DOLLARS     F    D   PR
# 0   253422  1114   0   1  43000  75305      1     6.99  NONE  0.0  0.0
# 1   253422  1114   0   1  43000  70170      2    13.98  NONE  0.0  0.0

# %%
delivery.head(2)
# Out:
#    IRI_KEY  OU    EST_ACV        Market_Name  Open  Clsd MskdName
# 0   200039  GR   9.709999  BUFFALO/ROCHESTER   539  1219  Chain87
# 1   200171  GR  27.690990          MILWAUKEE   522  9998  Chain97

# %%
display("The merged DataFrame")
df= pd.merge(delivery, coffee , on = "IRI_KEY", how = "inner")
# Out:
# 'The merged DataFrame'

# %%
df.head(2)
# Out:
#    IRI_KEY  OU   EST_ACV        Market_Name  Open  Clsd MskdName  WEEK  SY  \
# 0   200039  GR  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87  1114   0
# 1   200039  GR  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87  1114   0
#
#    GE   VEND   ITEM  UNITS  DOLLARS     F    D   PR
# 0   1  43000  75105      5    12.45  NONE  0.0  1.0
# 1   1  43000  75305      5    29.95  NONE  0.0  1.0

# %%
df= pd.merge(df, time , on = "WEEK", how = "inner")
df.head(10)
# Out:
#    IRI_KEY  OU   EST_ACV        Market_Name  Open  Clsd MskdName  WEEK  SY  \
# 0   200039  GR  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87  1138   0
# 1   200039  GR  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87  1138   0
# 2   200039  GR  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87  1138   0
# 3   200039  GR  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87  1138   0
# 4   200039  GR  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87  1138   0
# 5   200039  GR  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87  1138   0
# 6   200039  GR  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87  1138   0
# 7   200039  GR  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87  1138   0
# 8   200039  GR  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87  1138   0
# 9   200039  GR  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87  1138   0
#
#    GE  ...  Calendar week ending on  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# ...

# %%
df= df.drop(['Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11'], axis = 1)

# %%
df.head(2)
# Out:
#    IRI_KEY  OU   EST_ACV        Market_Name  Open  Clsd MskdName  WEEK  SY  \
# 0   200039  GR  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87  1138   0
# 1   200039  GR  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87  1138   0
#
#    GE   VEND   ITEM  UNITS  DOLLARS  F    D   PR Calendar week starting on  \
# 0   1  43000  75105     16     40.0  A  0.0  1.0                 18-Jun-01
# 1   3  43000  70150     11     27.5  A  0.0  1.0                 18-Jun-01
#
#   Calendar week ending on
# 0               24-Jun-01
# 1               24-Jun-01

# %%
df.isna().sum()
# Out:
# IRI_KEY                      0
# OU                           0
# EST_ACV                      0
# Market_Name                  0
# Open                         0
# Clsd                         0
# MskdName                     0
# WEEK                         0
# SY                           0
# GE                           0
# VEND                         0
# ITEM                         0
# UNITS                        0
# DOLLARS                      0
# F                            0
# D                            0
# PR                           0
# Calendar week starting on    0
# Calendar week ending on      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3203604 entries, 0 to 3203603
# Data columns (total 19 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   IRI_KEY                    int64
#  1   OU                         object
#  2   EST_ACV                    float64
#  3   Market_Name                object
#  4   Open                       int64
#  5   Clsd                       int64
#  6   MskdName                   object
#  7   WEEK                       int64
#  8   SY                         int64
#  9   GE                         int64
#  10  VEND                       int64
#  11  ITEM                       int64
#  12  UNITS                      int64
#  13  DOLLARS                    float64
#  14  F                          object
#  15  D                          float64
#  16  PR                         float64
#  17  Calendar week starting on  object
#  18  Calendar week ending on    object
# ...

# %%
df.['SY'] = "% s" % a

# %%
df["UPC"] = df["SY"] + df["GE"] + df['VEND'] + df['ITEM']

# %%
#df= df.drop(['WEEK','SY','GE','OU','Calendar week ending on'], axis=1)
df= df.drop(['WEEK','OU','Calendar week ending on'], axis=1)

# %%
df = df.rename(columns = {'Calendar week starting on':'WEEK'})

# %%
df.head(2)
# Out:
#    IRI_KEY   EST_ACV        Market_Name  Open  Clsd MskdName  SY  GE   VEND  \
# 0   200039  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87   0   1  43000
# 1   200039  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87   0   3  43000
#
#     ITEM  UNITS  DOLLARS  F    D   PR       WEEK     UPC
# 0  75105     16     40.0  A  0.0  1.0  18-Jun-01  118106
# 1  70150     11     27.5  A  0.0  1.0  18-Jun-01  113153

# %%
# Weekly Dollar sales by Store
#weekly_sales = df.drop(['VEND','PR','F','D','ITEM','Open', 'Clsd'], axis = 1)
weekly_sales = df.drop(['VEND','PR','F','D','ITEM','Open', 'Clsd','SY','GE'], axis = 1)
weekly_sales.head(4)
# Out:
#    IRI_KEY   EST_ACV        Market_Name MskdName  UNITS  DOLLARS       WEEK  \
# 0   200039  9.709999  BUFFALO/ROCHESTER  Chain87     16    40.00  18-Jun-01
# 1   200039  9.709999  BUFFALO/ROCHESTER  Chain87     11    27.50  18-Jun-01
# 2   200039  9.709999  BUFFALO/ROCHESTER  Chain87      6    15.00  18-Jun-01
# 3   200039  9.709999  BUFFALO/ROCHESTER  Chain87      3    23.97  18-Jun-01
#
#       UPC
# 0  118106
# 1  113153
# 2  113911
# 3  113523

# %%
weekly_sales = weekly_sales.groupby(['IRI_KEY', 'WEEK']).sum()

# %%
weekly_sales.head(2)
# Out:
#                       EST_ACV  UNITS  DOLLARS      UPC
# IRI_KEY WEEK
# 200039  1-Oct-01   737.959924    255  1085.75  6933452
#         10-Dec-01  669.989931    267  1056.81  6108967

# %%
Store_sales = df.groupby(['IRI_KEY']).sum()
Store_sales.head(2)
# Out:
#                EST_ACV     Open      Clsd     SY    GE       VEND       ITEM  \
# IRI_KEY
# 200039    18206.248125  1010625   2285625  17259  2982   90733375   77071599
# 200171   137458.074360  2591208  49630072  18762  6202  229142184  131356028
#
#          UNITS    DOLLARS     D      PR        UPC
# IRI_KEY
# 200039    9628   33734.06  50.0   619.0  167825215
# 200171   38103  131870.79  82.0  1070.0  360523176

# %%
df.to_csv (r'\Desktop\merged.csv', index = False, header=True)

# %%
df_weekly = df.groupby(['IRI_KEY', 'WEEK'])['EST_ACV','UNITS','DOLLARS'].sum()
df_weekly.head(6)
# Out:
# <ipython-input-86-fe3b41bb64a8>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_weekly = df.groupby(['IRI_KEY', 'WEEK'])['EST_ACV','UNITS','DOLLARS'].sum()
#                       EST_ACV  UNITS  DOLLARS
# IRI_KEY WEEK
# 200039  1-Oct-01   737.959924    255  1085.75
#         10-Dec-01  669.989931    267  1056.81
#         10-Sep-01  660.279932    272   974.49
#         12-Nov-01  689.409929    576  2185.97
#         13-Aug-01  504.919948    190   761.63
#         15-Oct-01  650.569933    269   905.21

# %%
df.head(3)
# Out:
#    IRI_KEY   EST_ACV        Market_Name  Open  Clsd MskdName  SY  GE   VEND  \
# 0   200039  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87   0   1  43000
# 1   200039  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87   0   3  43000
# 2   200039  9.709999  BUFFALO/ROCHESTER   539  1219  Chain87   0   1  43000
#
#     ITEM  UNITS  DOLLARS  F    D   PR       WEEK     UPC
# 0  75105     16     40.0  A  0.0  1.0  18-Jun-01  118106
# 1  70150     11     27.5  A  0.0  1.0  18-Jun-01  113153
# 2  70910      6     15.0  A  0.0  1.0  18-Jun-01  113911

# %%
store_open = df['Clsd'] - df['Open']
store_open
# Out:
# 0           680
# 1           680
# 2           680
# 3           680
# 4           680
#            ...
# 3203599    8879
# 3203600    8879
# 3203601    8879
# 3203602    8879
# 3203603    8879
# Length: 3203604, dtype: int64

# %%
df = df.drop(['MskdName'], axis =1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-c9e3005d8f23> in <module>
# ----> 1 df = df.drop(['MskdName'], axis =1)
#       2 df.shape
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
feature = df.groupby(['F', 'ITEM'])['EST_ACV','UNITS','DOLLARS'].sum()
feature.head(2)
# Out:
# <ipython-input-101-3c78e0375386>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   feature = df.groupby(['F', 'ITEM'])['EST_ACV','UNITS','DOLLARS'].sum()
#              EST_ACV   UNITS    DOLLARS
# F ITEM
# A 1     18808.138835  135227  214053.44
#   3      3888.317679   16397   66057.84

# %%
feature.to_csv (r'feature.csv', index = True , header= False)

# %%
feature.shape
# Out:
# (4734, 3)

# %%
products = pd.read_csv('prod_coffee.csv')

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6929 entries, 0 to 6928
# Data columns (total 21 columns):
#  #   Column                                                                            Non-Null Count  Dtype
# ---  ------                                                                            --------------  -----
#  0   L1                                                                                6929 non-null   object
#  1   L2                                                                                6929 non-null   object
#  2   L3                                                                                6929 non-null   object
#  3   L4                                                                                6929 non-null   object
#  4   L5                                                                                6929 non-null   object
# ...

# %%
products['L5'].value_counts()['STARBUCKS']
# Out:
# 151

# %%
flavours = products.groupby(['L5','FLAVOR/SCENT'])

# %%
flavours= products.loc[products['L5'] == 'STARBUCKS', 'FLAVOR/SCENT']
flavours
# Out:
# 187          MISSING
# 188          MISSING
# 189          MISSING
# 190         ASSORTED
# 191         ASSORTED
#             ...
# 4454    WINTER BLEND
# 4455    WINTER BLEND
# 4456    WINTER BLEND
# 4457         MISSING
# 4458         MISSING
# Name: FLAVOR/SCENT, Length: 151, dtype: object

# %%
flavours.describe()
# Out:
# count         151
# unique         26
# top       MISSING
# freq           42
# Name: FLAVOR/SCENT, dtype: object

# %%
flavours.value_counts()
# Out:
# MISSING               42
# HOUSE BLEND           24
# FRENCH ROAST          12
# BREAKFAST BLEND       11
# CHRISTMAS BLEND       10
# SUMATRA                7
# COLOMBIAN              6
# ESPRESSO ROAST         6
# REGULAR                5
# ASSORTED               4
# WINTER BLEND           3
# ITALIAN ROAST          3
# ESPRESSO               2
# VERONA                 2
# CAFE VERONA            2
# GAZEBO BLEND           2
# MOCHA                  1
# BLEND                  1
# COLUMBIAN SUPREME      1
# ETHIOPIA SIDAMO        1
# PEABERRY               1
# CHOCOLATE ESPRESSO     1
# SPECIAL BLEND          1
# TANZANIA               1
# VIENNESE BLEND         1
# SEASONAL BLEND         1
# Name: FLAVOR/SCENT, dtype: int64

# %%
flavours = flavours[flavours != 'MISSING']

# %%
flavours.value_counts()
# Out:
# HOUSE BLEND           24
# FRENCH ROAST          12
# BREAKFAST BLEND       11
# CHRISTMAS BLEND       10
# SUMATRA                7
# COLOMBIAN              6
# ESPRESSO ROAST         6
# REGULAR                5
# ASSORTED               4
# WINTER BLEND           3
# ITALIAN ROAST          3
# ESPRESSO               2
# VERONA                 2
# CAFE VERONA            2
# GAZEBO BLEND           2
# MOCHA                  1
# BLEND                  1
# COLUMBIAN SUPREME      1
# ETHIOPIA SIDAMO        1
# PEABERRY               1
# CHOCOLATE ESPRESSO     1
# SPECIAL BLEND          1
# TANZANIA               1
# VIENNESE BLEND         1
# SEASONAL BLEND         1
# Name: FLAVOR/SCENT, dtype: int64

# %%
flavours.to_csv (r'flavours.csv', index = False, header=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-05fd0af40ae8> in <module>
# ----> 1 flavours.to_xlxs (r'flavours.csv', index = False, header=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'to_xlxs'
